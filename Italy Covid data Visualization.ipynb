# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("owid-covid-data.csv")  
# since file is alreday present in same dirrectory where this python code is so path is not required. 
# Also do not copy paste the path of file as it will cause error due to invisible string.
# data =  pd.read_csv(r"c:\users...\filename.csv")  Note : r is used to ignore backspace sequesnce
# data =  pd.read_csv("c:/users.../filename.csv")   Note : removed r and changed \ to /
#data.head()

# %%
data
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 92327      ZWE    Africa     Zimbabwe  2021-05-26      38819.0      113.0
# 92328      ZWE    Africa     Zimbabwe  2021-05-27      38854.0       35.0
# 92329      ZWE    Africa     Zimbabwe  2021-05-28      38918.0       64.0
# 92330      ZWE    Africa     Zimbabwe  2021-05-29      38933.0       15.0
# 92331      ZWE    Africa     Zimbabwe  2021-05-30      38944.0       11.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
data.tail()
# Out:
#       iso_code continent  location        date  total_cases  new_cases  \
# 92327      ZWE    Africa  Zimbabwe  2021-05-26      38819.0      113.0
# 92328      ZWE    Africa  Zimbabwe  2021-05-27      38854.0       35.0
# 92329      ZWE    Africa  Zimbabwe  2021-05-28      38918.0       64.0
# 92330      ZWE    Africa  Zimbabwe  2021-05-29      38933.0       15.0
# 92331      ZWE    Africa  Zimbabwe  2021-05-30      38944.0       11.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 92327              29.571        1589.0         2.0                0.857  ...
# 92328              31.286        1592.0         3.0                1.000  ...
# 92329              36.286        1592.0         0.0                0.857  ...
# 92330              36.286        1594.0         2.0                1.143  ...
# 92331              37.429        1594.0         0.0                1.143  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
data.describe() # used to describe the data with basic details like 
# count, mean, std, max etc
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  8.954900e+04   89548.000000        88536.000000  7.964200e+04
# mean   9.389156e+05    6060.785400         6075.183356  2.528245e+04
# std    6.480837e+06   38287.309112        37867.395017  1.507138e+05
# min    1.000000e+00 -348667.000000        -6223.000000  1.000000e+00
# 25%    1.086000e+03       2.000000            7.143000  4.900000e+01
# 50%    1.193200e+04      71.000000           88.429000  3.380000e+02
# 75%    1.266060e+05     787.000000          826.321750  3.300000e+03
# max    1.703485e+08  905992.000000       826374.286000  3.541324e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  79800.000000         88536.000000             89070.000000
# mean     142.217256           127.084010             11521.388928
# std      781.312585           721.056227             21704.895372
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
data.isnull() # to find out all the values where null values are available in data or table
# Out:
#        iso_code  continent  location   date  total_cases  new_cases  \
# 0         False      False     False  False        False      False
# 1         False      False     False  False        False      False
# 2         False      False     False  False        False      False
# 3         False      False     False  False        False      False
# 4         False      False     False  False        False      False
# ...         ...        ...       ...    ...          ...        ...
# 92327     False      False     False  False        False      False
# 92328     False      False     False  False        False      False
# 92329     False      False     False  False        False      False
# 92330     False      False     False  False        False      False
# 92331     False      False     False  False        False      False
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
data.isnull().sum() # used to get sum of no. of rows having null in each column
# Out:
# iso_code                                     0
# continent                                 4381
# location                                     0
# date                                         0
# total_cases                               2783
# new_cases                                 2784
# new_cases_smoothed                        3796
# total_deaths                             12690
# new_deaths                               12532
# new_deaths_smoothed                       3796
# total_cases_per_million                   3262
# new_cases_per_million                     3263
# new_cases_smoothed_per_million            4270
# total_deaths_per_million                 13156
# new_deaths_per_million                   12998
# new_deaths_smoothed_per_million           4270
# reproduction_rate                        18045
# icu_patients                             83005
# icu_patients_per_million                 83005
# hosp_patients                            80738
# ...

# %% [markdown]
# # Relating the variables with scatterplots.

# %%
sns.relplot(x= "total_cases", y = "total_deaths", data = data)
# read more about relplot from : https://towardsdatascience.com/master-a-third-of-seaborn-statistical-plotting-with-relplot-df8642718f0f#:~:text=Seaborn%20provides%20three%20high-level%20functions%20which%20encompass%20most,including%20how%20to%20create%20subplots%20and%20many%20more.

# %%
sns.pairplot(data) # will give almost all possible plots between different column
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9f33636b51d6> in <module>
# ----> 1 sns.pairplot(data)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1987     # Set up the PairGrid
#    1988     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 1989     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1990                     hue_order=hue_order, palette=palette, corner=corner,
# ...

# %%
sns.catplot(x='total_cases', y='total_deaths', data=data)
